# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
data = pd.read_csv("output/housing_data1.csv")

# %%
data
# Out:
#      price                                              title  distance  \
# 0   2775.0  3 BED 3 BATH - PRIVATE ENSUITE BATHROOM FOR EV...        20
# 1   2455.0  MODERN 3-Bedroom Apartment Downtown - 5 Mins t...         5
# 2   2625.0  Renovated from top to bottom! 3 Bedroom - Avai...        20
# 3   1950.0  2 Bedroom, Available May 1st, 2021 - 10 MINS F...        10
# 4   2673.0  RENOVATED 3-Bedroom Apartment - 5 Mins to Quee...         5
# ..     ...                                                ...       ...
# 60   590.0  ASAP - Looking for Sublet for Jan 1st utilitie...        20
# 61  1900.0    WANTED: Apartment/house near Queen's University        20
# 62   600.0          Single Room for rent all inclusive 600.00        20
# 63   570.0  Looking for  2 Student/Young Professional Room...        20
# 64   550.0  STUDENT RENTAL, ONE BEDROOM AVAIL STEPS TO PEN...        20
#
#     date-posted  location                                        description  \
# 0       7012021  Kingston  Starting at $925/Bedroom per Month Private ens...
# 1      17012021  Kingston  3D virtual tour available â€“ contact for deta...
# 2       7012021  Kingston  It is a beautiful spacious unit in a great loc...
# 3      14012021  Kingston  Just 10 minutes to Queen's University, and ste...
# 4      17012021  Kingston  Completely renovated, 3-bedroom apartment is o...
# ..          ...       ...                                                ...
# 60     29112020  Kingston  I'm looking for someone to sublet my room or t...
# 61     29112020  Kingston  Hello, we are two female students from the Fac...
# 62     28112020  Kingston  One second floor bedroom for Rent 600 , includ...
# 63     24112020  Kingston  Looking for two students/young professionals r...
# 64     24112020  Kingston  LOOKING FOR MALE TENANT , ONE BEDROOM IN A THR...
#
#     beds  baths
# 0      3      3
# 1      3      1
# 2      3      1
# 3      1      1
# 4      3      1
# ..   ...    ...
# 60     1      1
# 61     1      1
# 62     1      1
# 63     1      1
# 64     1      1
#
# [65 rows x 8 columns]

# %%
# Get rid of rows with NaN price
data = data[data['price'].notna()]
data.head()
# Out:
#     price                                              title  distance  \
# 0  2775.0  3 BED 3 BATH - PRIVATE ENSUITE BATHROOM FOR EV...        20
# 1  2455.0  MODERN 3-Bedroom Apartment Downtown - 5 Mins t...         5
# 2  2625.0  Renovated from top to bottom! 3 Bedroom - Avai...        20
# 3  1950.0  2 Bedroom, Available May 1st, 2021 - 10 MINS F...        10
# 4  2673.0  RENOVATED 3-Bedroom Apartment - 5 Mins to Quee...         5
#
#    date-posted  location                                        description  \
# 0      7012021  Kingston  Starting at $925/Bedroom per Month Private ens...
# 1     17012021  Kingston  3D virtual tour available â€“ contact for deta...
# 2      7012021  Kingston  It is a beautiful spacious unit in a great loc...
# 3     14012021  Kingston  Just 10 minutes to Queen's University, and ste...
# 4     17012021  Kingston  Completely renovated, 3-bedroom apartment is o...
#
#    beds  baths
# 0     3      3
# 1     3      1
# 2     3      1
# 3     1      1
# 4     3      1

# %%
labels = data['price']
train1 = data.drop(['title','price', 'description', 'location'],axis=1)
train1.head()
# Out:
#    distance  date-posted  beds  baths
# 0        20      7012021     3      3
# 1         5     17012021     3      1
# 2        20      7012021     3      1
# 3        10     14012021     1      1
# 4         5     17012021     3      1

# %%
# Fill in NA
train1 = train1.fillna(20)
train1.head()
# Out:
#    distance  date-posted  beds  baths
# 0        20      7012021     3      3
# 1         5     17012021     3      1
# 2        20      7012021     3      1
# 3        10     14012021     1      1
# 4         5     17012021     3      1

# %%
# Lets try a bit better
from sklearn import ensemble
import numpy as np

from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(train1, labels, test_size=0.1, random_state=69)

# %%
clf = ensemble.GradientBoostingRegressor(n_estimators=400, max_depth=5, min_samples_split=2, learning_rate=0.1, loss='ls')

# %%
clf.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=200)

# %%
clf.score(X_test, y_test) # Need more feature points
# Out:
# 0.44886514071927175

# %%
key_data = pd.read_csv("data\key_stone_data.csv")
key_data.head()
# Out:
#                                     address  bedrooms date-available  \
# 0          233 Brock St., Kingston, Ontario         1  February 2021
# 1        200-7 Queen St., Kingston, Ontario         1  February 2021
# 2  272.5-17 Princess St., Kingston, Ontario         1  February 2021
# 3   272.5-3 Princess St., Kingston, Ontario         1       May 2021
# 4        200-2 Queen St., Kingston, Ontario         1  February 2021
#
#              landlords  price                         title  \
# 0  Keystone Properties    795  Shared Accommodation- Rooms
# 1  Keystone Properties   1295            Bachelor Apartment
# 2  Keystone Properties   1295            Bachelor Apartment
# 3  Keystone Properties   1495           Bachelor Apartment
# 4  Keystone Properties   1495           1 Bedroom Apartment
#
#                    url  A/C  electric  heat
# 0   listing.html?id=52    1         1     1
# 1  listing.html?id=189    0         0     1
# 2  listing.html?id=142    0         0     0
# 3  listing.html?id=129    0         0     0
# 4  listing.html?id=185    0         0     1

# %%
labels = key_data['price']
train2 = key_data.drop(['price', 'address', 'landlords', 'title', 'url'],axis=1)
train2.head()
# Out:
#    bedrooms  A/C  electric  heat
# 0         1    1         1     1
# 1         1    0         0     1
# 2         1    0         0     0
# 3         1    0         0     0
# 4         1    0         0     1

# %%
X_train, X_test, y_train, y_test = train_test_split(train2, labels, test_size=0.5, random_state=69)

# %%
clf = ensemble.GradientBoostingRegressor(n_estimators=400, max_depth=5, min_samples_split=2, learning_rate=0.1, loss='ls')

# %%
clf.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=400)

# %%
clf.score(X_test, y_test) # Need more feature points
# Out:
# 0.13448797416119107
