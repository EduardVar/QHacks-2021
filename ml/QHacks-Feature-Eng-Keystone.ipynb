# %%
import pandas as pd 
import numpy as np

from re import sub
from decimal import Decimal
from datetime import datetime

import json 
import csv 

# Opening JSON file and loading the data 
# into the variable data 
with open('data/keystone-output.json') as json_file: 
    data = json.load(json_file)

# %%
data[0].keys()
# Out:
# dict_keys(['address', 'bedrooms', 'date-available', 'landlords', 'price', 'title', 'url', 'utilites'])

# %%
# Keywords
bedId = ["bed", "bedroom", "bedrooms","bdrm", "beds"]
bathId = ["bath", "baths", "bathroom", "bathrooms", "rest", "rests", "restroom", "restrooms"]
minuteId = ["min", "mins", "minutes", "minute", "minutes"]

bad = ["food", "promo", "commercial"]
monthToNum = {"January":"1", "February":"2", "March":"3", "April":"4", "May":"5", 
              "June":"6", "July":"7", "August":"8", "September":"9", 
              "October":"10", "November":"11", "December":"12"}

textDic = {"one": 1, "two": 2, "three": 3, "four": 4, "five":5, 
           "six": 6, "seven": 7, "eight": 8, "nine": 9, "ten": 10}

# %%
int(data[0]["utilites"]["electric"])
# Out:
# 1

# %%
# Custom cols
cols =list(data[0].keys())
cols = cols[:-1] + ["A/C", "electric", "heat"]

# Build the dataframe
clean_df = pd.DataFrame(columns=cols)
                
i = 0
for line in data:
    
    price = 0
    try:
        price = round(Decimal(sub(r'[^\d.]', '', line["price"][1:line["price"].index("/")])))
    except:
        price = np.nan
      
    date = ""
    split_date = line['date-available'].split()
    try:
        date = "01" + monthToNum[split_date[0]] + split_date[1]
    except:
        date = datetime.today().strftime('%d%m%Y')
    
    clean_df.loc[i] = [line['address'], line['bedrooms'], date, 
                       line['landlords'], price, line['title'], line['url'], 
                       int(line["utilites"]["A/C"]), 
                       int(line["utilites"]["electric"]),
                       int(line["utilites"]["heat"])]
    
    i += 1

# %%
clean_df
# Out:
#                                      address bedrooms date-available  \
# 0           233 Brock St., Kingston, Ontario        1        0122021
# 1         200-7 Queen St., Kingston, Ontario        1        0122021
# 2   272.5-17 Princess St., Kingston, Ontario        1        0122021
# 3    272.5-3 Princess St., Kingston, Ontario        1        0152021
# 4         200-2 Queen St., Kingston, Ontario        1        0122021
# 5      194-4 Sydenham St., Kingston, Ontario        1        0152021
# 6      265-5 Princess St., Kingston, Ontario        1        0122021
# 7   272.5-22 Princess St., Kingston, Ontario        1        0122021
# 8   272.5-13 Princess St., Kingston, Ontario        1        0122021
# 9       314-2 Princess St, Kingston, Ontario        1        0122021
# 10  272.5-11 Princess St., Kingston, Ontario        1        0122021
# 11   267-307 Princess St., Kingston, Ontario        1        0152021
# 12     322-2 Princess St., Kingston, Ontario        2       23012021
# 13     332-4 Princess St., Kingston, Ontario        2        0152021
# 14     322-1 Princess St., Kingston, Ontario        2       23012021
# 15  272.5-16 Princess St., Kingston, Ontario        2        0152021
# 16   267-201 Princess St., Kingston, Ontario        2        0122021
# 17   186-202 Sydenham St., Kingston, Ontario        3        0122021
# 18     289-2 Princess St., Kingston, Ontario        3        0152021
#
#               landlords price                         title  \
# 0   Keystone Properties   795  Shared Accommodation- Rooms
# 1   Keystone Properties  1295            Bachelor Apartment
# 2   Keystone Properties  1295            Bachelor Apartment
# 3   Keystone Properties  1495           Bachelor Apartment
# 4   Keystone Properties  1495           1 Bedroom Apartment
# 5   Keystone Properties  1495           1 Bedroom Apartment
# 6   Keystone Properties  1695           1 Bedroom Apartment
# 7   Keystone Properties  1695           1 Bedroom Apartment
# 8   Keystone Properties  1767           1 Bedroom Apartment
# 9   Keystone Properties  1795           1 Bedroom Apartment
# 10  Keystone Properties  1795           1 Bedroom Apartment
# 11  Keystone Properties  1920           1 Bedroom Apartment
# 12  Keystone Properties  1712           Beautiful 2 bedroom
# 13  Keystone Properties  1838           2 Bedroom Apartment
# 14  Keystone Properties  1838           2 Bedroom Apartment
# 15  Keystone Properties  1848           2 Bedroom Apartment
# 16  Keystone Properties  2398           2 Bedroom Apartment
# 17  Keystone Properties  2595          3 Bedroom Apartment
# 18  Keystone Properties  2604           3 Bedroom Apartment
#
#                     url A/C electric heat
# 0    listing.html?id=52   1        1    1
# 1   listing.html?id=189   0        0    1
# 2   listing.html?id=142   0        0    0
# 3   listing.html?id=129   0        0    0
# 4   listing.html?id=185   0        0    1
# 5   listing.html?id=220   0        0    1
# 6    listing.html?id=93   0        0    0
# 7   listing.html?id=147   0        0    0
# 8   listing.html?id=138   0        0    0
# 9   listing.html?id=156   0        0    0
# 10  listing.html?id=136   0        0    0
# 11  listing.html?id=126   1        0    0
# 12  listing.html?id=164   1        0    1
# 13  listing.html?id=172   0        0    0
# 14  listing.html?id=163   0        0    1
# 15  listing.html?id=141   0        0    0
# 16  listing.html?id=113   0        0    0
# 17  listing.html?id=216   0        0    0
# 18  listing.html?id=149   0        0    0

# %%
clean_df.to_csv(r'C:\\Eduard\\Projects\\GitHub\\QHacks-2021\\ml\\data\key_stone_data.csv', index = False)
